# %%
import pandas
data = pandas.read_excel("Holocene_Volcanoes.xlsx", sheet_name="Holocene Volcano List")

data
# Out:
#                                          Volcano Number  \
# 0                                                210010
# 1                                                210020
# 2                                                210030
# 3                                                210040
# 4                                                211003
# ...                                                 ...
# 1418                                             390130
# 1419                                             390140
# 1420                                             390829
# 1421                                             390847
# 1422  Global Volcanism Program - Volcanoes of the Wo...
#
#                    Volcano Name         Country  \
# 0     West Eifel Volcanic Field         Germany
# 1               Chaine des Puys          France
# 2           Olot Volcanic Field           Spain
# 3      Calatrava Volcanic Field           Spain
# ...
